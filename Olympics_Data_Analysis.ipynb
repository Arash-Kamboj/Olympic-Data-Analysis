# %% [markdown]
# <a href="https://colab.research.google.com/github/Arash-Kamboj/Olympic-Data-Analysis/blob/main/Olympics_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()

# %% [markdown]
# # **Task 1: Data Loading and Overview**
# **1. Data Loading and Overview:**
#
# The analysis begin by loading the dataset, named "Olympics.csv" into a Pandas DataFrame and then display the first few rows of the DataFrame to provide an initial overview of the data's structure and content.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/Olympics.csv')
df.head()
# Out:
#                 Name Sex   Age  Height  Weight     Team  Year  Season  \
# 0      Andreea Aanei   F  22.0   170.0   125.0  Romania  2016  Summer
# 1  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  2016  Summer
# 2  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  2016  Summer
# 3  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  2016  Summer
# 4  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  2016  Summer
#
#         Host_City Host_Country          Sport  \
# 0  Rio de Janeiro       Brazil  Weightlifting
# 1  Rio de Janeiro       Brazil     Gymnastics
# 2  Rio de Janeiro       Brazil     Gymnastics
# 3  Rio de Janeiro       Brazil     Gymnastics
# 4  Rio de Janeiro       Brazil     Gymnastics
#
#                                      Event  GDP_Per_Capita_Constant_LCU_Value  \
# 0  Weightlifting Women's Super-Heavyweight                        20450.34567
# 1   Gymnastics Men's Individual All-Around                        23788.15345
# 2          Gymnastics Men's Floor Exercise                        23788.15345
# 3           Gymnastics Men's Parallel Bars                        23788.15345
# 4          Gymnastics Men's Horizontal Bar                        23788.15345
#
#    Representing_Host Avg_Temp  Medal
# 0                  0      8.8      0
# 1                  0     13.3      0
# 2                  0     13.3      0
# 3                  0     13.3      0
# 4                  0     13.3      0

# %% [markdown]
# **2. Summary of the Dataset**
#
# To ensure data integrity, we perform a thorough data quality check.

# %%
print('Data types and missing values:\n')
df.info()
# Out:
# Data types and missing values:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202616 entries, 0 to 202615
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Name                               202616 non-null  object
#  1   Sex                                202616 non-null  object
#  2   Age                                202616 non-null  float64
#  3   Height                             202615 non-null  float64
#  4   Weight                             202615 non-null  float64
#  5   Team                               202616 non-null  object
#  6   Year                               202616 non-null  int64
#  7   Season                             202616 non-null  object
#  8   Host_City                          202616 non-null  object
#  9   Host_Country                       202616 non-null  object
#  10  Sport                              202616 non-null  object
#  11  Event                              202616 non-null  object
#  12  GDP_Per_Capita_Constant_LCU_Value  202616 non-null  float64
#  13  Representing_Host                  202616 non-null  int64
#  14  Avg_Temp                           202616 non-null  object
#  15  Medal                              202616 non-null  int64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 24.7+ MB

# %% [markdown]
# **3. Descriptive Statistics:**
#
# In this step, To gain insights into the dataset's numerical features, we calculate summary statistics for numeric columns.

# %%
print("Summary statistics for numeric columns:")
df.describe(include = 'all')
# Out:
# Summary statistics for numeric columns:
#                   Name     Sex            Age         Height         Weight  \
# count           202616  202616  202616.000000  202615.000000  202615.000000
# unique          100178       2            NaN            NaN            NaN
# top     Andreas Wecker       M            NaN            NaN            NaN
# freq                32  135131            NaN            NaN            NaN
# mean               NaN     NaN      24.966480     175.298414      70.576962
# std                NaN     NaN       5.472054      10.483912      14.263095
# min                NaN     NaN      11.000000     127.000000      25.000000
# 25%                NaN     NaN      21.000000     168.000000      60.000000
# 50%                NaN     NaN      24.000000     175.000000      70.000000
# 75%                NaN     NaN      28.000000     182.000000      79.000000
# max                NaN     NaN      71.000000     226.000000     214.000000
#
#            Team           Year  Season Host_City   Host_Country      Sport  \
# count    202616  202616.000000  202616    202616         202616     202616
# unique      203            NaN       2        29             18         51
# top     Germany            NaN  Summer   Atlanta  United States  Athletics
# freq      12779            NaN  161230     13675          29798      27555
# mean        NaN    1992.252626     NaN       NaN            NaN        NaN
# std         NaN      16.518691     NaN       NaN            NaN        NaN
# min         NaN    1960.000000     NaN       NaN            NaN        NaN
# 25%         NaN    1980.000000     NaN       NaN            NaN        NaN
# 50%         NaN    1996.000000     NaN       NaN            NaN        NaN
# 75%         NaN    2006.000000     NaN       NaN            NaN        NaN
# max         NaN    2016.000000     NaN       NaN            NaN        NaN
#
#                           Event  GDP_Per_Capita_Constant_LCU_Value  \
# count                    202616                       2.026160e+05
# unique                      489                                NaN
# top     Football Men's Football                                NaN
# freq                       3670                                NaN
# mean                        NaN                       1.016396e+06
# std                         NaN                       5.839650e+06
# min                         NaN                       2.321763e+02
# 25%                         NaN                       1.671118e+04
# 50%                         NaN                       3.046682e+04
# 75%                         NaN                       1.329136e+05
# max                         NaN                       1.313372e+08
#
#         Representing_Host Avg_Temp          Medal
# count       202616.000000   202616  202616.000000
# unique                NaN      148            NaN
# top                   NaN      8.5            NaN
# freq                  NaN    12779            NaN
# mean             0.057977      NaN       0.268345
# std              0.233700      NaN       0.743768
# min              0.000000      NaN       0.000000
# 25%              0.000000      NaN       0.000000
# 50%              0.000000      NaN       0.000000
# 75%              0.000000      NaN       0.000000
# max              1.000000      NaN       3.000000

# %% [markdown]
# **4. Count Number of Unique Values:**
#
# Understanding the diversity and uniqueness of categorical variables is essential for event planning and engagement strategies. Analyze the results to understand the variety of responses and preferences among residents.
#
#
# ---

# %%
print("\nSummary statistics for numeric columns:")
print(df.nunique())
# Out:
# Summary statistics for numeric columns:
# Name                                 100178
# Sex                                       2
# Age                                     231
# Height                                  492
# Weight                                  631
# Team                                    203
# Year                                     21
# Season                                    2
# Host_City                                29
# Host_Country                             18
# Sport                                    51
# Event                                   489
# GDP_Per_Capita_Constant_LCU_Value      2497
# Representing_Host                         2
# Avg_Temp                                148
# Medal                                     4
# dtype: int64

# %% [markdown]
# **4. Count Number of Unique Values:**
#
# Understanding the diversity and uniqueness of categorical variables is essential for event planning and engagement strategies. Analyze the results to understand the variety of responses and preferences among residents.
#
#
#
# ---

# %%
for i in df.columns:
  print(f"\nCheck unique values in {i} column:")
  print( print(df[i].unique()))
# Out:
# Check unique values in Name column:
# ['Andreea Aanei' 'Nstor Abad Sanjun' 'Antonio Abadia Beci' ...
#  'Edward uawnik' 'Edward "Eddie" Zwier'
#  'Petronella Veronica Maria "Nel" Zwier']
# None
#
# Check unique values in Sex column:
# ['F' 'M']
# None
#
#  'Iran, Islamic Rep.' 'Belgium' 'Cameroon' 'Kazakhstan'
#  'Brunei Darussalam' 'Uzbekistan' 'Tajikistan' 'Russian Federation'
#  'Canada' 'Germany' 'Mexico' 'Ethiopia' 'Sri Lanka' 'Armenia' 'Kenya'
#  'Nigeria' 'Brazil' 'Australia' 'Chile' 'Switzerland' 'Belarus' 'Guyana'
#  'Georgia' 'Portugal' 'Colombia' 'Djibouti' 'Jordan' 'West Bank and Gaza'
#  'Saudi Arabia' 'India' 'Ghana' 'Honduras' 'El Salvador' 'Venezuela, RB'
#  'Argentina' 'Turkmenistan' 'Japan' 'St. Kitts and Nevis' 'United Kingdom'
#  'New Zealand' 'Turkey' 'Eritrea' 'Uganda' 'Mongolia' 'Lithuania'
#  'Namibia' 'Kyrgyz Republic' 'Puerto Rico' 'Malaysia' 'Samoa' 'Angola'
#  'South Africa' 'Greece' 'Norway' 'Cuba' 'Paraguay' 'Indonesia'
#  'Bangladesh' "Cote d'Ivoire" 'Trinidad and Tobago' 'China' 'Singapore'
#  'Morocco' 'Sweden' 'Ukraine' 'Tunisia' 'Oman' 'Qatar'
#  'United Arab Emirates' 'Moldova' 'Mauritius' 'Bulgaria' 'Serbia'
#  'St. Vincent and the Grenadines' 'Austria' 'Niger' 'Costa Rica' 'Sudan'
#  'Madagascar' 'Pakistan' 'Chad' 'Bosnia and Herzegovina' 'Philippines'
#  'Cayman Islands' 'Syrian Arab Republic' 'Jamaica' 'Estonia' 'Seychelles'
#  'Ecuador' 'Panama' 'Gabon' 'Bahamas, The' 'Israel' 'Thailand' 'Botswana'
#  'Korea, Rep.' 'Denmark' 'Cabo Verde' 'Poland' 'Dominican Republic'
#  'Hungary' 'Czech Republic' 'Benin' 'Uruguay' 'Latvia' 'Andorra' 'Cyprus'
#  'Comoros' 'Libya' 'Hong Kong SAR, China' 'St. Lucia' 'Mozambique'
#  'Micronesia, Fed. Sts.' 'Togo' 'Mauritania' 'Yemen, Rep.' 'Croatia'
#  'Antigua and Barbuda' 'Afghanistan' 'Slovak Republic' 'Guinea' 'Fiji'
#  'Lebanon' 'Montenegro' 'Guatemala' 'Papua New Guinea' 'Zimbabwe'
#  'Gambia, The' 'Slovenia' 'Barbados' 'Malta' 'Nepal'
#  'Sao Tome and Principe' 'Congo, Rep.' 'Central African Republic'
#  'Senegal' 'Peru' 'Nauru' 'Guinea-Bissau' 'Lao PDR' 'Rwanda' 'Timor-Leste'
#  'Albania' 'Luxembourg' 'Haiti' 'Bolivia' 'Finland' 'Grenada' 'Zambia'
#  'Malawi' 'Korea, Dem. People’s Rep.' 'Cambodia' 'Virgin Islands (U.S.)'
#  'Mali' 'Marshall Islands' 'Monaco' 'Palau' 'Vietnam' 'Bermuda' 'Dominica'
#  'Equatorial Guinea' 'Tonga' 'Solomon Islands' 'Burundi' 'Kosovo'
#  'Iceland' 'British Virgin Islands' 'South Sudan' 'Liechtenstein'
#  'Tanzania' 'Myanmar' 'Guam' 'Maldives' 'Sierra Leone' 'Belize'
#  'American Samoa' 'Congo, Dem. Rep.' 'Bhutan' 'Kiribati' 'Burkina Faso'
#  'Suriname' 'Liberia' 'Nicaragua' 'Lesotho' 'Vanuatu' 'Aruba' 'Eswatini'
#  'Somalia' 'San Marino' 'Tuvalu' 'Kuwait']
# None
#
# Check unique values in Year column:
# [2016 2014 2012 2010 2008 2006 2004 2002 2000 1998 1996 1994 1992 1988
#  1984 1980 1976 1972 1968 1964 1960]
# None
#
# Check unique values in Season column:
# ['Summer' 'Winter']
# None
#
# Check unique values in Host_City column:
# ['Rio de Janeiro' 'Sochi' 'London' 'Vancouver' 'Beijing' 'Torino' 'Athina'
#  'Salt Lake City' 'Sydney' 'Nagano' 'Atlanta' 'Lillehammer' 'Barcelona'
#  'Albertville' 'Calgary' 'Seoul' 'Sarajevo' 'Los Angeles' 'Lake Placid'
#  'Moskva' 'Montreal' 'Innsbruck' 'Munich' 'Sapporo' 'Mexico City'
#  'Grenoble' 'Tokyo' 'Squaw Valley' 'Roma']
# None
#
# Check unique values in Host_Country column:
# ['Brazil' 'Russian Federation' 'United Kingdom' 'Canada' 'China' 'Italy'
#  'Greece' 'United States' 'Australia' 'Japan' 'Norway' 'Spain' 'France'
#  'Korea, Dem. People’s Rep.' 'Bosnia and Herzegovina' 'Austria' 'Germany'
#  'Mexico']
# None
#
# Check unique values in Sport column:
# ['Weightlifting' 'Gymnastics' 'Athletics' 'Rowing' 'Taekwondo' 'Handball'
#  'Boxing' 'Equestrianism' 'Cycling' 'Volleyball' 'Diving' 'Shooting'
#  'Judo' 'Football' 'Synchronized Swimming' 'Wrestling' 'Fencing'
#  'Swimming' 'Badminton' 'Rugby Sevens' 'Table Tennis' 'Water Polo'
#  'Trampolining' 'Basketball' 'Triathlon' 'Modern Pentathlon' 'Sailing'
#  'Beach Volleyball' 'Golf' 'Rhythmic Gymnastics' 'Archery' 'Hockey'
#  'Canoeing' 'Tennis' 'Ice Hockey' 'Alpine Skiing' 'Figure Skating'
#  'Freestyle Skiing' 'Biathlon' 'Curling' 'Cross Country Skiing'
#  'Ski Jumping' 'Luge' 'Short Track Speed Skating' 'Snowboarding'
#  'Speed Skating' 'Skeleton' 'Bobsleigh' 'Nordic Combined' 'Softball'
#  'Baseball']
# None
#
# Check unique values in Event column:
# ["Weightlifting Women's Super-Heavyweight"
#  "Gymnastics Men's Individual All-Around"
#  "Gymnastics Men's Floor Exercise" "Gymnastics Men's Parallel Bars"
#  "Gymnastics Men's Horizontal Bar" "Gymnastics Men's Rings"
#  "Gymnastics Men's Pommelled Horse" "Athletics Men's 5,000 metres"
#  "Rowing Men's Coxless Pairs" "Taekwondo Women's Flyweight"
#  "Handball Men's Handball" "Boxing Men's Middleweight"
#  "Athletics Men's 400 metres" "Handball Women's Handball"
#  "Weightlifting Men's Heavyweight"
#  'Equestrianism Mixed Three-Day Event, Individual'
#  'Equestrianism Mixed Three-Day Event, Team'
#  "Cycling Women's Road Race, Individual" "Volleyball Men's Volleyball"
#  "Diving Women's Platform" "Shooting Men's Air Pistol, 10 metres"
#  "Shooting Men's Free Pistol, 50 metres"
#  "Shooting Women's Air Rifle, 10 metres" "Boxing Men's Lightweight"
#  "Judo Men's Half-Middleweight" "Weightlifting Men's Middleweight"
#  "Weightlifting Men's Middle-Heavyweight" "Football Men's Football"
#  "Synchronized Swimming Women's Team" "Judo Men's Extra-Lightweight"
#  "Wrestling Men's Middleweight, Greco-Roman"
#  "Athletics Men's 10,000 metres" "Volleyball Women's Volleyball"
#  "Athletics Women's 200 metres" "Boxing Men's Heavyweight"
#  "Wrestling Men's Super-Heavyweight, Greco-Roman"
#  "Wrestling Men's Middleweight, Freestyle" "Judo Men's Heavyweight"
#  "Fencing Men's Sabre, Individual" "Diving Women's Springboard"
#  "Diving Women's Synchronized Springboard" "Athletics Men's Decathlon"
#  "Athletics Men's Marathon" "Swimming Men's 100 metres Freestyle"
#  "Boxing Men's Flyweight" "Badminton Men's Singles"
#  "Rugby Sevens Women's Rugby Sevens" "Football Women's Football"
#  "Table Tennis Men's Team" "Water Polo Women's Water Polo"
#  "Gymnastics Men's Team All-Around" "Gymnastics Men's Horse Vault"
#  "Swimming Men's 50 metres Freestyle"
#  "Swimming Men's 4 x 100 metres Freestyle Relay"
#  "Fencing Men's Foil, Individual" "Fencing Men's Foil, Team"
#  "Rowing Women's Lightweight Double Sculls" "Athletics Women's Shot Put"
#  "Athletics Women's 400 metres" "Athletics Men's Shot Put"
#  "Trampolining Men's Individual" "Athletics Women's Marathon"
#  "Basketball Men's Basketball" "Triathlon Women's Olympic Distance"
#  "Cycling Men's Mountainbike, Cross-Country"
#  "Taekwondo Men's Featherweight" "Athletics Men's 100 metres"
#  "Athletics Women's 100 metres" "Swimming Men's 100 metres Backstroke"
#  "Swimming Men's 4 x 100 metres Medley Relay"
#  "Synchronized Swimming Women's Duet" "Table Tennis Men's Singles"
#  "Athletics Women's 4 x 100 metres Relay" "Basketball Women's Basketball"
#  "Rowing Women's Quadruple Sculls" "Weightlifting Men's Featherweight"
#  "Swimming Men's 200 metres Freestyle"
#  "Swimming Men's 400 metres Freestyle"
#  "Swimming Men's 1,500 metres Freestyle"
#  "Wrestling Women's Light-Heavyweight, Freestyle"
#  "Water Polo Men's Water Polo" "Rowing Men's Coxless Fours"
#  "Trampolining Women's Individual" "Athletics Men's 200 metres"
#  "Athletics Men's 4 x 100 metres Relay"
#  "Swimming Women's 200 metres Butterfly" "Rowing Women's Double Sculls"
#  "Boxing Women's Flyweight" "Shooting Men's Skeet"
#  "Wrestling Women's Heavyweight, Freestyle" 'Badminton Mixed Doubles'
#  "Wrestling Women's Featherweight, Freestyle"
#  "Rugby Sevens Men's Rugby Sevens"
#  "Wrestling Women's Lightweight, Freestyle"
#  "Modern Pentathlon Women's Individual" "Judo Women's Half-Lightweight"
#  "Athletics Men's High Jump" "Rowing Men's Quadruple Sculls"
#  "Boxing Men's Light-Heavyweight" "Sailing Men's One Person Dinghy"
#  "Swimming Women's 100 metres Backstroke"
#  "Sailing Men's Two Person Dinghy"
#  'Equestrianism Mixed Dressage, Individual' "Rowing Men's Coxed Eights"
#  "Judo Women's Half-Middleweight" "Sailing Women's Skiff"
#  "Athletics Men's Triple Jump" "Beach Volleyball Women's Beach Volleyball"
#  "Athletics Women's Heptathlon" "Golf Men's Individual"
#  "Rhythmic Gymnastics Women's Group" "Athletics Women's Javelin Throw"
#  "Archery Women's Individual" "Archery Women's Team"
#  "Hockey Women's Hockey" "Weightlifting Women's Flyweight"
#  "Athletics Women's Pole Vault" 'Equestrianism Mixed Jumping, Individual'
#  'Equestrianism Mixed Jumping, Team' "Weightlifting Women's Middleweight"
#  "Shooting Women's Trap" "Badminton Men's Doubles"
#  "Swimming Women's 200 metres Freestyle"
#  "Swimming Women's 4 x 200 metres Freestyle Relay"
#  "Athletics Women's 20 kilometres Walk"
#  "Canoeing Men's Kayak Singles, Slalom" "Rowing Women's Single Sculls"
#  "Cycling Men's Road Race, Individual" "Boxing Men's Super-Heavyweight"
#  "Athletics Women's 3,000 metres Steeplechase"
#  "Athletics Men's 3,000 metres Steeplechase"
#  "Wrestling Men's Super-Heavyweight, Freestyle"
#  "Canoeing Women's Kayak Fours, 500 metres"
#  "Wrestling Men's Light-Heavyweight, Greco-Roman"
#  "Boxing Men's Bantamweight" "Shooting Men's Rapid-Fire Pistol, 25 metres"
#  "Athletics Women's 800 metres" "Athletics Women's 1,500 metres"
#  "Fencing Women's Sabre, Team" "Swimming Women's 50 metres Freestyle"
#  "Weightlifting Women's Lightweight"
#  "Shooting Women's Air Pistol, 10 metres" "Athletics Men's Discus Throw"
#  "Weightlifting Men's Lightweight" "Shooting Men's Double Trap"
#  "Boxing Men's Light-Welterweight" "Rowing Men's Single Sculls"
#  "Shooting Men's Small-Bore Rifle, Three Positions, 50 metres"
#  "Fencing Women's Foil, Individual" "Athletics Men's 1,500 metres"
#  "Fencing Men's epee, Individual" "Sailing Women's Windsurfer"
#  "Cycling Men's Individual Time Trial" "Triathlon Men's Olympic Distance"
#  "Taekwondo Men's Heavyweight" "Rowing Women's Coxed Eights"
#  "Wrestling Men's Welterweight, Greco-Roman" "Tennis Men's Singles"
#  'Sailing Mixed Multihull' "Rowing Men's Lightweight Coxless Fours"
#  "Hockey Men's Hockey" "Sailing Women's Two Person Dinghy"
#  "Athletics Men's 400 metres Hurdles" "Rowing Men's Double Sculls"
#  "Wrestling Men's Heavyweight, Greco-Roman"
#  "Weightlifting Men's Super-Heavyweight" "Boxing Women's Lightweight"
#  "Canoeing Men's Kayak Doubles, 1,000 metres"
#  "Athletics Women's Long Jump" "Athletics Men's 110 metres Hurdles"
#  "Athletics Women's 100 metres Hurdles" "Athletics Women's 5,000 metres"
#  "Shooting Men's Trap" "Beach Volleyball Men's Beach Volleyball"
#  "Taekwondo Women's Featherweight" "Swimming Women's 100 metres Freestyle"
#  "Sailing Women's One Person Dinghy" "Table Tennis Women's Singles"
#  "Athletics Men's 4 x 400 metres Relay"
#  "Swimming Men's 200 metres Breaststroke"
#  "Swimming Men's 400 metres Individual Medley"
#  "Swimming Men's 200 metres Butterfly"
#  'Equestrianism Mixed Dressage, Team' "Taekwondo Women's Heavyweight"
#  "Gymnastics Women's Team All-Around" "Gymnastics Women's Uneven Bars"
#  "Gymnastics Women's Balance Beam" "Judo Women's Heavyweight"
#  "Canoeing Men's Canadian Singles, 1,000 metres"
#  "Archery Men's Individual" "Archery Men's Team"
#  "Judo Women's Middleweight" "Athletics Men's Long Jump"
#  "Gymnastics Women's Individual All-Around"
#  "Gymnastics Women's Floor Exercise" "Athletics Men's 800 metres"
#  "Judo Women's Lightweight" "Athletics Women's High Jump"
#  "Athletics Men's Javelin Throw"
#  "Canoeing Women's Kayak Singles, 200 metres"
#  "Athletics Women's 4 x 400 metres Relay"
#  "Wrestling Men's Light-Heavyweight, Freestyle"
#  "Weightlifting Men's Light-Heavyweight" "Judo Men's Half-Lightweight"
#  "Judo Men's Lightweight" "Swimming Women's 100 metres Butterfly"
#  "Athletics Women's 400 metres Hurdles" "Athletics Women's Discus Throw"
#  "Canoeing Women's Kayak Singles, 500 metres"
#  "Athletics Men's Hammer Throw" "Rowing Women's Coxless Pairs"
#  "Swimming Women's 10 kilometres Open Water"
#  "Athletics Women's 10,000 metres"
#  "Swimming Women's 200 metres Breaststroke"
#  "Swimming Women's 4 x 100 metres Freestyle Relay"
#  "Swimming Women's 200 metres Individual Medley"
#  "Wrestling Men's Heavyweight, Freestyle"
#  "Swimming Men's 4 x 200 metres Freestyle Relay"
#  "Cycling Women's Team Pursuit" "Fencing Men's epee, Team"
#  "Canoeing Men's Kayak Singles, 1,000 metres"
#  "Canoeing Men's Kayak Fours, 1,000 metres"
#  "Wrestling Men's Featherweight, Freestyle"
#  "Canoeing Men's Canadian Doubles, Slalom"
#  "Canoeing Women's Kayak Doubles, 500 metres"
#  "Fencing Women's Sabre, Individual" "Judo Men's Half-Heavyweight"
#  "Athletics Men's 50 kilometres Walk" "Athletics Men's 20 kilometres Walk"
#  "Boxing Men's Welterweight" "Athletics Men's Pole Vault"
#  "Boxing Men's Light-Flyweight" "Cycling Women's Individual Time Trial"
#  "Shooting Women's Small-Bore Rifle, Three Positions, 50 metres"
#  "Weightlifting Women's Heavyweight"
#  "Shooting Women's Sporting Pistol, 25 metres"
#  "Swimming Men's 200 metres Individual Medley"
#  "Rhythmic Gymnastics Women's Individual" "Golf Women's Individual"
#  "Taekwondo Men's Flyweight" "Swimming Women's 400 metres Freestyle"
#  "Swimming Women's 800 metres Freestyle" "Athletics Women's Triple Jump"
#  "Swimming Women's 100 metres Breaststroke"
#  "Swimming Women's 4 x 100 metres Medley Relay" "Diving Men's Platform"
#  "Wrestling Women's Flyweight, Freestyle"
#  "Weightlifting Women's Light-Heavyweight"
#  "Swimming Women's 200 metres Backstroke" "Cycling Men's Keirin"
#  "Swimming Men's 10 kilometres Open Water" "Diving Men's Springboard"
#  "Rowing Men's Lightweight Double Sculls"
#  "Shooting Men's Air Rifle, 10 metres" "Tennis Women's Singles"
#  "Tennis Women's Doubles" "Shooting Women's Skeet"
#  "Badminton Women's Singles" "Tennis Men's Doubles"
#  "Judo Men's Middleweight" "Swimming Men's 100 metres Breaststroke"
#  "Boxing Women's Middleweight"
#  "Swimming Women's 400 metres Individual Medley" "Sailing Men's Skiff"
#  "Taekwondo Women's Welterweight"
#  "Wrestling Men's Welterweight, Freestyle"
#  "Cycling Women's Mountainbike, Cross-Country" "Cycling Men's Sprint"
#  "Cycling Men's Team Sprint" "Cycling Women's Keirin"
#  "Wrestling Men's Featherweight, Greco-Roman"
#  "Canoeing Men's Kayak Singles, 200 metres"
#  "Canoeing Men's Kayak Doubles, 200 metres"
#  "Swimming Men's 200 metres Backstroke"
#  "Cycling Men's Team Pursuit, 4,000 metres" 'Tennis Mixed Doubles'
#  "Taekwondo Men's Welterweight" "Gymnastics Women's Horse Vault"
#  "Modern Pentathlon Men's Individual" "Fencing Women's epee, Individual"
#  "Fencing Women's epee, Team"
#  "Canoeing Men's Canadian Singles, 200 metres"
#  "Diving Women's Synchronized Platform"
#  "Canoeing Men's Canadian Singles, Slalom"
#  "Sailing Men's One Person Heavyweight Dinghy" "Sailing Men's Windsurfer"
#  "Athletics Women's Hammer Throw" "Cycling Women's Omnium"
#  "Cycling Women's BMX" "Cycling Men's Omnium"
#  "Diving Men's Synchronized Platform" "Weightlifting Men's Bantamweight"
#  "Shooting Men's Small-Bore Rifle, Prone, 50 metres"
#  "Canoeing Men's Canadian Doubles, 1,000 metres" "Cycling Men's BMX"
#  "Weightlifting Women's Featherweight" "Cycling Women's Sprint"
#  "Cycling Women's Team Sprint" "Diving Men's Synchronized Springboard"
#  "Judo Women's Extra-Lightweight" "Judo Women's Half-Heavyweight"
#  "Badminton Women's Doubles" "Table Tennis Women's Team"
#  "Canoeing Women's Kayak Singles, Slalom"
#  "Swimming Men's 100 metres Butterfly"
#  "Wrestling Women's Middleweight, Freestyle" "Ice Hockey Men's Ice Hockey"
#  "Alpine Skiing Women's Slalom" "Figure Skating Men's Singles"
#  'Figure Skating Mixed Team' "Alpine Skiing Women's Super G"
#  "Alpine Skiing Women's Giant Slalom" "Alpine Skiing Men's Giant Slalom"
#  "Alpine Skiing Men's Slalom" "Freestyle Skiing Men's Aerials"
#  "Biathlon Men's 10 kilometres Sprint"
#  'Biathlon Mixed 2 x 6 kilometres and 2 x 7.5 kilometres Relay'
#  "Biathlon Men's 12.5 kilometres Pursuit" "Biathlon Men's 20 kilometres"
#  "Biathlon Men's 4 x 7.5 kilometres Relay" "Alpine Skiing Men's Downhill"
#  "Alpine Skiing Men's Combined" "Ice Hockey Women's Ice Hockey"
#  "Curling Women's Curling" "Freestyle Skiing Men's Slopestyle"
#  "Freestyle Skiing Women's Halfpipe" 'Figure Skating Mixed Ice Dancing'
#  "Cross Country Skiing Women's 30 kilometres"
#  "Cross Country Skiing Women's 15 km Skiathlon"
#  "Ski Jumping Men's Normal Hill, Individual"
#  "Ski Jumping Men's Large Hill, Individual"
#  "Ski Jumping Men's Large Hill, Team"
#  "Cross Country Skiing Men's 15 kilometres"
#  "Cross Country Skiing Men's 50 kilometres" "Luge Women's Singles"
#  "Alpine Skiing Women's Downhill" "Alpine Skiing Women's Combined"
#  "Freestyle Skiing Women's Aerials" "Alpine Skiing Men's Super G"
#  "Ski Jumping Women's Normal Hill, Individual"
#  "Short Track Speed Skating Men's 500 metres"
#  "Short Track Speed Skating Men's 1,000 metres"
#  "Short Track Speed Skating Men's 1,500 metres"
#  "Short Track Speed Skating Men's 5,000 metres Relay"
#  "Cross Country Skiing Women's 10 kilometres"
#  "Snowboarding Women's Slopestyle"
#  "Snowboarding Men's Parallel Giant Slalom"
#  "Snowboarding Men's Parallel Slalom" "Speed Skating Men's 1,000 metres"
#  "Speed Skating Men's 1,500 metres" "Curling Men's Curling"
#  "Cross Country Skiing Men's Sprint" "Cross Country Skiing Women's Sprint"
#  "Cross Country Skiing Men's 30 km Skiathlon"
#  "Cross Country Skiing Men's 4 x 10 kilometres Relay"
#  "Speed Skating Women's 1,000 metres" "Speed Skating Women's 1,500 metres"
#  "Snowboarding Women's Boardercross" "Skeleton Men's Skeleton"
#  "Luge Mixed (Men)'s Doubles" 'Luge Mixed Team Relay'
#  "Cross Country Skiing Women's 4 x 5 kilometres Relay"
#  "Snowboarding Men's Halfpipe" "Bobsleigh Men's Two"
#  "Bobsleigh Men's Four" "Figure Skating Women's Singles"
#  "Speed Skating Women's 500 metres"
#  "Cross Country Skiing Women's Team Sprint"
#  "Speed Skating Men's 5,000 metres" "Speed Skating Men's 10,000 metres"
#  "Speed Skating Men's 500 metres"
#  "Biathlon Men's 15 kilometres Mass Start"
#  "Freestyle Skiing Women's Slopestyle"
#  "Cross Country Skiing Men's Team Sprint"
#  "Snowboarding Men's Boardercross" "Luge Men's Singles"
#  "Freestyle Skiing Men's Moguls" "Biathlon Women's 15 kilometres"
#  "Freestyle Skiing Women's Ski Cross" 'Figure Skating Mixed Pairs'
#  "Nordic Combined Men's Normal Hill / 10 km, Individual"
#  "Nordic Combined Men's Large Hill / 10 km, Individual"
#  "Nordic Combined Men's Team" "Speed Skating Women's 3,000 metres"
#  "Speed Skating Women's 5,000 metres"
#  "Short Track Speed Skating Women's 1,000 metres"
#  "Short Track Speed Skating Women's 1,500 metres"
#  "Short Track Speed Skating Women's 3,000 metres Relay"
#  "Biathlon Women's 7.5 kilometres Sprint"
#  "Biathlon Women's 10 kilometres Pursuit"
#  "Biathlon Women's 12.5 kilometres Mass Start"
#  "Biathlon Women's 4 x 6 kilometres Relay" "Snowboarding Men's Slopestyle"
#  "Freestyle Skiing Men's Halfpipe"
#  "Speed Skating Men's Team Pursuit (8 laps)"
#  "Speed Skating Women's Team Pursuit (6 laps)"
#  "Snowboarding Women's Parallel Giant Slalom"
#  "Snowboarding Women's Parallel Slalom" "Freestyle Skiing Men's Ski Cross"
#  "Short Track Speed Skating Women's 500 metres"
#  "Snowboarding Women's Halfpipe" "Skeleton Women's Skeleton"
#  "Bobsleigh Women's Two" "Freestyle Skiing Women's Moguls"
#  "Wrestling Men's Lightweight, Greco-Roman" "Fencing Women's Foil, Team"
#  "Sailing Women's Three Person Keelboat"
#  "Sailing Men's Two Person Keelboat"
#  "Wrestling Men's Lightweight, Freestyle" "Fencing Men's Sabre, Team"
#  "Softball Women's Softball" "Baseball Men's Baseball"
#  "Canoeing Men's Kayak Singles, 500 metres"
#  "Canoeing Men's Canadian Doubles, 500 metres"
#  'Sailing Mixed One Person Dinghy'
#  "Cycling Men's Individual Pursuit, 4,000 metres" 'Sailing Mixed Skiff'
#  "Boxing Men's Featherweight" "Cycling Men's Points Race"
#  "Canoeing Men's Kayak Doubles, 500 metres"
#  "Canoeing Men's Canadian Singles, 500 metres"
#  "Cycling Women's Points Race" "Cycling Men's Madison"
#  "Cycling Women's Individual Pursuit, 3,000 metres"
#  "Nordic Combined Men's Individual" "Nordic Combined Men's Sprint"
#  "Cycling Women's 500 metres Time Trial" "Table Tennis Men's Doubles"
#  "Shooting Men's Running Target, 10 metres" "Shooting Women's Double Trap"
#  "Table Tennis Women's Doubles" "Cycling Men's 1,000 metres Time Trial"
#  "Biathlon Women's 4 x 7.5 kilometres Relay"
#  "Cross Country Skiing Women's 15 kilometres"
#  "Cross Country Skiing Women's 5/5 kilometres Pursuit"
#  "Cross Country Skiing Men's 30 kilometres"
#  "Cross Country Skiing Men's 10/10 kilometres Pursuit"
#  'Sailing Mixed Three Person Keelboat'
#  "Wrestling Men's Bantamweight, Freestyle"
#  "Wrestling Men's Bantamweight, Greco-Roman"
#  'Sailing Mixed Two Person Keelboat' "Boxing Men's Light-Middleweight"
#  "Cross Country Skiing Men's 10 kilometres"
#  "Cross Country Skiing Men's 10/15 kilometres Pursuit"
#  "Cross Country Skiing Women's 5 kilometres"
#  "Cross Country Skiing Women's 5/10 kilometres Pursuit"
#  "Snowboarding Men's Giant Slalom" "Snowboarding Women's Giant Slalom"
#  "Wrestling Men's Flyweight, Freestyle" "Weightlifting Men's Flyweight"
#  "Wrestling Men's Light-Flyweight, Greco-Roman"
#  "Weightlifting Men's Heavyweight I"
#  "Wrestling Men's Flyweight, Greco-Roman"
#  "Athletics Women's 10 kilometres Walk"
#  "Weightlifting Men's Heavyweight II"
#  "Wrestling Men's Light-Flyweight, Freestyle" 'Shooting Mixed Skeet'
#  "Rowing Men's Coxed Pairs" "Modern Pentathlon Men's Team"
#  "Cycling Men's 100 kilometres Team Time Trial"
#  'Sailing Mixed Two Person Heavyweight Dinghy'
#  "Synchronized Swimming Women's Solo" 'Shooting Mixed Trap'
#  "Biathlon Women's 3 x 7.5 kilometres Relay" "Rowing Men's Coxed Fours"
#  "Rowing Women's Coxless Fours" "Athletics Women's 3,000 metres"
#  "Cross Country Skiing Women's 20 kilometres" 'Sailing Mixed Windsurfer'
#  "Rowing Women's Coxed Fours" "Shooting Men's Running Target, 50 metres"
#  'Sailing Mixed Two Person Dinghy' "Rowing Women's Coxed Quadruple Sculls"
#  "Judo Men's Open Class"
#  'Shooting Mixed Small-Bore Rifle, Three Positions, 50 metres'
#  'Shooting Mixed Small-Bore Rifle, Prone, 50 metres'
#  "Athletics Women's Pentathlon" 'Shooting Mixed Running Target, 50 metres'
#  'Shooting Mixed Free Pistol, 50 metres'
#  'Shooting Mixed Rapid-Fire Pistol, 25 metres'
#  'Shooting Mixed Free Rifle, Three Positions, 300 metres'
#  "Cross Country Skiing Women's 3 x 5 kilometres Relay"
#  "Cycling Men's Tandem Sprint, 2,000 metres"
#  "Athletics Women's 80 metres Hurdles" 'Sailing Mixed 5.5 metres'
#  "Shooting Men's Free Rifle, Three Positions, 300 metres"
#  "Canoeing Men's Kayak Relay 4 x 500 metres"
#  "Equestrianism Men's Three-Day Event, Individual"
#  "Equestrianism Men's Three-Day Event, Team"]
# None
#
# Check unique values in GDP_Per_Capita_Constant_LCU_Value column:
# [20450.34567  23788.15345  25912.00778  ...  4621.659378  1990.230348
#   3723.089281]
# None
#
# Check unique values in Representing_Host column:
# [0 1]
# None
#
# Check unique values in Avg_Temp column:
# ['8.8' '13.3' '13.45' '11.95' '10.7' '22.5' '27.15' '9.25' '21.4' '9.3'
#  '8.55' '22.1' '17.25' '9.55' '24.6' '6.4' '0' '12.05' '2' '−5.10' '8.5'
#  '21' '22.2' '26.95' '7.15' '24.75' '26.8' '24.95' '21.65' '8.45' '5.5'
#  '6.15' '26' '5.8' '15.15' '24.5' '28' '18.3' '24.65' '23.65' '27.2'
#  '23.5' '24.45' '25.35' '14.8' '15.1' '11.15' '10.55' '11.1' '25.5' '22.8'
#  '−0.70' '6.2' '19.95' '1.55' '25.4' '26.7' '21.55' '17.75' '15.4' '1.5'
#  '25.2' '23.55' '25.85' '25' '26.35' '25.75' '6.95' '26.45' '17.1' '2.1'
#  '8.3' '19.2' '25.6' '27' '9.45' '22.4' '6.35' '24.8' '26.9' '22.65'
#  '20.2' '26.55' '9.85' '5.1' '21.85' '25.05' '24.85' '26.3' '21.5' '11.5'
#  '7.5' '23.3' '7.85' '24.55' '9.75' '7.55' '27.55' '17.55' '5.6' '7.6'
#  '18.45' '25.55' '21.8' '23.8' '27.65' '23.85' '10.9' '12.6' '6.8' '25.7'
#  '24.4' '16.4' '23.45' '25.25' '27.5' '8.9' '8.1' '23.75' '24.9' '27.85'
#  '19.6' '26.75' '17.85' '11.4' '8.65' '1.7' '26.65' '21.9' '5.7' '28.25'
#  '27.4' '13.55' '27.6' '22.35' '25.65' '19.8' '1.75' '5.65' '13.05'
#  '26.05' '25.3' '24' '7.4' '28.2' '11.85' '23.95' '27.05']
# None
#
# Check unique values in Medal column:
# [0 1 2 3]
# None

# %% [markdown]
# **6. Checking for Missing Values:**
#
# Identify and report missing values in the dataset, which may require data imputation or further data collection strategies.
#
#
#
# ---

# %%
print("\nMissing values count in each column:")
df.isnull().sum()
# Out:
# Missing values count in each column:
# Name                                 0
# Sex                                  0
# Age                                  0
# Height                               1
# Weight                               1
# Team                                 0
# Year                                 0
# Season                               0
# Host_City                            0
# Host_Country                         0
# Sport                                0
# Event                                0
# GDP_Per_Capita_Constant_LCU_Value    0
# Representing_Host                    0
# Avg_Temp                             0
# Medal                                0
# dtype: int64

# %% [markdown]
# **7. Check for Duplicate Values:**
#
# One important aspect of data quality is identifying and handling duplicated data. We utilise the duplicated() method in pandas to check for duplicated rows within the dataset. The sum() function is then applied to count the total number of duplicated rows. Duplicated data can introduce bias and inaccuracies into our analysis, so it's essential to address it appropriately.
#
#
# ---

# %%
print(f"Duplicate values count in the Dataframe: {df.duplicated().sum()}")
# Out:
# Duplicate values count in the Dataframe: 0

# %% [markdown]
# **8.Data Type Conversion:**
#
# We ensure that relevant columns are of the correct data types for analysis.
#
#
# ---

# %%
# Data Type Conversion

df['Avg_Temp'] = pd.to_numeric(df['Avg_Temp'], errors='coerce')  # Convert to numeric, converting errors to NaN
print(f"Data type of 'Avg_Temp' column : {df['Avg_Temp'].dtypes}")
# Out:
# Data type of 'Avg_Temp' column : float64

# %% [markdown]
# Data sanitisation after the data conversion of 'Avg_Temp'. Check again if any new null values are created.
#
#
# ---

# %%
df.isnull().sum()
# Out:
# Name                                     0
# Sex                                      0
# Age                                      0
# Height                                   1
# Weight                                   1
# Team                                     0
# Year                                     0
# Season                                   0
# Host_City                                0
# Host_Country                             0
# Sport                                    0
# Event                                    0
# GDP_Per_Capita_Constant_LCU_Value        0
# Representing_Host                        0
# Avg_Temp                             10134
# Medal                                    0
# dtype: int64

# %% [markdown]
# **9.Handling missing values.**
#
# Impute missing Values in 'Avg_Temp' using median.
#
# ---

# %%
 # Replace missing values in 'Avg_Temp' with median
df['Avg_Temp'] = df['Avg_Temp'].fillna(df['Avg_Temp'].median())
df.isnull().sum()
# Out:
# Name                                 0
# Sex                                  0
# Age                                  0
# Height                               1
# Weight                               1
# Team                                 0
# Year                                 0
# Season                               0
# Host_City                            0
# Host_Country                         0
# Sport                                0
# Event                                0
# GDP_Per_Capita_Constant_LCU_Value    0
# Representing_Host                    0
# Avg_Temp                             0
# Medal                                0
# dtype: int64

# %% [markdown]
# **10. Imputing missing values.**
#
# Impute lissing values in 'Height and 'Weight' based on the corresponding 'Age' value
# .
#
# ---

# %%
# Creating avg_height variable
avg_height= df.groupby('Age')['Height'].median().to_dict()

# Iterate rows to replace missing values in 'Height'
for index, row in df.iterrows():
    if pd.isnull(row['Height']):
        avg_age = row['Age']
        if avg_age in avg_height:
            df.at[index, 'Height'] = avg_height[avg_age]


# Creating avg_weight variable
avg_weight= df.groupby('Age')['Weight'].median().to_dict()

# Iterate rows to replace missing values in 'Weight'
for index, row in df.iterrows():
    if pd.isnull(row['Weight']):
        avg_age = row['Age']
        if avg_age in avg_weight:
           df.at[index, 'Weight'] = avg_weight[avg_age]

df.isnull().sum()
# Out:
# Name                                 0
# Sex                                  0
# Age                                  0
# Height                               0
# Weight                               0
# Team                                 0
# Year                                 0
# Season                               0
# Host_City                            0
# Host_Country                         0
# Sport                                0
# Event                                0
# GDP_Per_Capita_Constant_LCU_Value    0
# Representing_Host                    0
# Avg_Temp                             0
# Medal                                0
# dtype: int64

# %%
# Show cleaned data summary
data_type = pd.DataFrame(df.dtypes, columns=['Data Type'])
missing = pd.DataFrame(df.isnull().sum(), columns=['Missing Values'])
missing_percentage = pd.DataFrame(round(df.isnull().mean() * 100,2), columns=['Missing Percentage'])
unique = pd.DataFrame(df.nunique(), columns=['Unique Values'])
sample = pd.DataFrame(df.head().T)

summary = pd.concat([data_type, missing, missing_percentage, unique, sample], axis=1)
summary.rename(columns={0: 'Row_1',
                        1: 'Row_2',
                        2: 'Row_3',
                        3: 'Row_4',
                        4: 'Row_5'
                       }, inplace=True)
summary
# Out:
#                                   Data Type  Missing Values  \
# Name                                 object               0
# Sex                                  object               0
# Age                                 float64               0
# Height                              float64               0
# Weight                              float64               0
# Team                                 object               0
# Year                                  int64               0
# Season                               object               0
# Host_City                            object               0
# Host_Country                         object               0
# Sport                                object               0
# Event                                object               0
# GDP_Per_Capita_Constant_LCU_Value   float64               0
# Representing_Host                     int64               0
# Avg_Temp                            float64               0
# Medal                                 int64               0
#
#                                    Missing Percentage  Unique Values  \
# Name                                              0.0         100178
# Sex                                               0.0              2
# Age                                               0.0            231
# Height                                            0.0            492
# Weight                                            0.0            631
# Team                                              0.0            203
# Year                                              0.0             21
# Season                                            0.0              2
# Host_City                                         0.0             29
# Host_Country                                      0.0             18
# Sport                                             0.0             51
# Event                                             0.0            489
# GDP_Per_Capita_Constant_LCU_Value                 0.0           2497
# Representing_Host                                 0.0              2
# Avg_Temp                                          0.0            146
# Medal                                             0.0              4
#
#                                                                      Row_1  \
# Name                                                         Andreea Aanei
# Sex                                                                      F
# Age                                                                   22.0
# Height                                                               170.0
# Weight                                                               125.0
# Team                                                               Romania
# Year                                                                  2016
# Season                                                              Summer
# Host_City                                                   Rio de Janeiro
# Host_Country                                                        Brazil
# Sport                                                        Weightlifting
# Event                              Weightlifting Women's Super-Heavyweight
# GDP_Per_Capita_Constant_LCU_Value                              20450.34567
# Representing_Host                                                        0
# Avg_Temp                                                               8.8
# Medal                                                                    0
#
#                                                                     Row_2  \
# Name                                                    Nstor Abad Sanjun
# Sex                                                                     M
# Age                                                                  23.0
# Height                                                              167.0
# Weight                                                               64.0
# Team                                                                Spain
# Year                                                                 2016
# Season                                                             Summer
# Host_City                                                  Rio de Janeiro
# Host_Country                                                       Brazil
# Sport                                                          Gymnastics
# Event                              Gymnastics Men's Individual All-Around
# GDP_Per_Capita_Constant_LCU_Value                             23788.15345
# Representing_Host                                                       0
# Avg_Temp                                                             13.3
# Medal                                                                   0
#
#                                                              Row_3  \
# Name                                             Nstor Abad Sanjun
# Sex                                                              M
# Age                                                           23.0
# Height                                                       167.0
# Weight                                                        64.0
# Team                                                         Spain
# Year                                                          2016
# Season                                                      Summer
# Host_City                                           Rio de Janeiro
# Host_Country                                                Brazil
# Sport                                                   Gymnastics
# Event                              Gymnastics Men's Floor Exercise
# GDP_Per_Capita_Constant_LCU_Value                      23788.15345
# Representing_Host                                                0
# Avg_Temp                                                      13.3
# Medal                                                            0
#
#                                                             Row_4  \
# Name                                            Nstor Abad Sanjun
# Sex                                                             M
# Age                                                          23.0
# Height                                                      167.0
# Weight                                                       64.0
# Team                                                        Spain
# Year                                                         2016
# Season                                                     Summer
# Host_City                                          Rio de Janeiro
# Host_Country                                               Brazil
# Sport                                                  Gymnastics
# Event                              Gymnastics Men's Parallel Bars
# GDP_Per_Capita_Constant_LCU_Value                     23788.15345
# Representing_Host                                               0
# Avg_Temp                                                     13.3
# Medal                                                           0
#
#                                                              Row_5
# Name                                             Nstor Abad Sanjun
# Sex                                                              M
# Age                                                           23.0
# Height                                                       167.0
# Weight                                                        64.0
# Team                                                         Spain
# Year                                                          2016
# Season                                                      Summer
# Host_City                                           Rio de Janeiro
# Host_Country                                                Brazil
# Sport                                                   Gymnastics
# Event                              Gymnastics Men's Horizontal Bar
# GDP_Per_Capita_Constant_LCU_Value                      23788.15345
# Representing_Host                                                0
# Avg_Temp                                                      13.3
# Medal                                                            0

# %% [markdown]
# *Since my data is now clean and does not include any missing or duplicated values. There is also no unncessary column to drop. So, I can further proceed to data analysis and data visualisation.*
# ---

# %% [markdown]
# **Finding Team with highest number of medals.**
#
#
# ---

# %%
medal_counts = df.groupby('Team')['Medal'].sum()

# Finding the country with the maximum sum of medals
country_with_max_medals = medal_counts.idxmax()
max_medals = medal_counts.max()

print("Country with maximum medals:", country_with_max_medals)
print("Number of medals won:", max_medals)
# Out:
# Country with maximum medals: United States
# Number of medals won: 8160

# %% [markdown]
# **Finding Sport with maximum number of medals.**
#
#
# ---

# %%
medal_counts = df.groupby('Sport')['Medal'].sum()

# Finding the country with the maximum sum of medals
Sport_with_max_medals = medal_counts.idxmax()
max_medals = medal_counts.max()

print("Sport with maximum medals:", Sport_with_max_medals)
print("Number of medals won:", max_medals)
# Out:
# Sport with maximum medals: Swimming
# Number of medals won: 4914

# %% [markdown]
# Finding Top 5 countries and their visual representation.

# %%
sorted_medal_counts = medal_counts.sort_values(ascending=False)

# Taking the top 5 teams
top_5_teams = sorted_medal_counts.head(5)
print("Top 5 teams based on the number of medals won:")
print(top_5_teams)

# Create a bar plot to visualize the distribution
plt.figure(figsize=(10,5))
sns.set_style("darkgrid")
sns.barplot(top_5_teams, palette='mako')
plt.title('Distribution of Origin', fontsize=14, fontweight='bold')
plt.xlabel('Origin of Owner', fontweight='bold')
plt.ylabel('Count', fontweight='bold')
plt.show()
# Out:
# Top 5 teams based on the number of medals won:
# Sport
# Swimming      4914
# Athletics     4899
# Rowing        3915
# Hockey        2331
# Ice Hockey    2206
# Name: Medal, dtype: int64

# %% [markdown]
# **Analysing relation between Weight and Age on gender basis.**
#
#
# ---

# %%
# Create a scatter plot
sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Weight', hue='Sex', data=df, palette='Set1',  s=50, color='blue', alpha=0.7)
plt.title('Scatter Plot', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Weight', fontsize=14)
sns.regplot(x='Age', y='Weight', data=df, scatter=False, color='red')
plt.show()

# %% [markdown]
# **Explanation of Scatterplot:**
#
# 1. Age is having lot of outliers and is heavily right skewed distribution
#
# 2. Height has outliers on both side but it is balanced and it shows normal distribution.
#
# 3. Weight has more outliers on right side thus making it right skewed.
#
# 4. Not much relation could be seen between Age and Weight but there seem to be slight positive correlation.
#
# 5. There's variability in weight within each gender at any given age, implying that factors beyond age also influence weight.
